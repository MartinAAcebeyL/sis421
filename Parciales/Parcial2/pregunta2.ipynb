# %%
# !pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9672 sha256=f046a8cb359715058d79a75bb1e3ea79496ffda532eebd97d9f7aa7c0e28a9f1
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
# !git clone https://github.com/pedropro/TACO.git
# Out:
# Cloning into 'TACO'...
# remote: Enumerating objects: 492, done.
# remote: Counting objects: 100% (222/222), done.
# remote: Compressing objects: 100% (145/145), done.
# remote: Total 492 (delta 162), reused 134 (delta 77), pack-reused 270
# Receiving objects: 100% (492/492), 69.39 MiB | 15.97 MiB/s, done.
# Resolving deltas: 100% (313/313), done.

# %%
# !ls
# Out:
# sample_data  TACO

# %%
# %cd TACO
# Out:
# /content/TACO

# %%
pip install -r requirements.txt

# %%
pip install git+https://github.com/philferriere/cocoapi.git#subdirectory=PythonAPI
# Out:
# Collecting git+https://github.com/philferriere/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/philferriere/cocoapi.git to /tmp/pip-req-build-18d8h2an
#   Running command git clone -q https://github.com/philferriere/cocoapi.git /tmp/pip-req-build-18d8h2an
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp37-cp37m-linux_x86_64.whl size=264154 sha256=6133e096b27782689fc4a9767deb592583692b1fbded1169061292354883aee4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6pw7huo_/wheels/6b/c6/c5/cb6da4cb793a6cb1ab91f6578d76c42686422127eb4dbcea94
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.3
#     Uninstalling pycocotools-2.0.3:
#       Successfully uninstalled pycocotools-2.0.3
# Successfully installed pycocotools-2.0

# %%
#!python download.py

# %%
sys.path.append("/content/Mask_RCNN/mrcnn")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-cd827f3498ab> in <module>()
# ----> 1 sys.path.append("/content/Mask_RCNN/mrcnn")
#
# NameError: name 'sys' is not defined

# %%
# !python3 download.py
