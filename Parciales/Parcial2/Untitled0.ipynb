# %%
# !pip install wget
# Out:
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9672 sha256=7d6caaf22a035c677ea773b7a68f0aba7dda771c51bbce1827060bded9338b1d
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# ...

# %%
import wget
url = 'https://dl.fbaipublicfiles.com/textvqa/images/test_images.zip'
wget.download(url)
# Out:
# 'test_images.zip'

# %%
import zipfile
#/content/test_images.zip
with zipfile.ZipFile('test_images.zip', 'r') as zip_ref:
    zip_ref.extractall('.')

# %%
url = 'https://dl.fbaipublicfiles.com/textvqa/images/train_val_images.zip'
wget.download(url)
with zipfile.ZipFile('train_val_images.zip', 'r') as zip_ref:
    zip_ref.extractall('.')

# %%
! git clone https://github.com/kristerseiya/WasteNet.git
# Out:
# Cloning into 'WasteNet'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 105 (delta 44), reused 87 (delta 26), pack-reused 0
# Receiving objects: 100% (105/105), 10.29 MiB | 25.26 MiB/s, done.
# Resolving deltas: 100% (44/44), done.

# %%
% cd WasteNet/
# Out:
# /content/WasteNet

# %%
! git pull origin main
# Out:
# From https://github.com/kristerseiya/WasteNet
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
import torch
from torch.utils.data import DataLoader
from torch.optim import Adam
import matplotlib.pyplot as plt

import data
import model
import run

from importlib import reload

# %%
reload(data)
reload(model)
reload(run)
# Out:
# <module 'run' from '/content/WasteNet/run.py'>

# %%
torch.cuda.empty_cache()

# %%
dataset_top_dir = '/content/gdrive/MyDrive/Dataset/WasteNet-resized'

dataset = data.WasteNetDataset([dataset_top_dir+'/data-resized', dataset_top_dir+'/data2-resized'],
                               store='ram', exclude=['google'])

# %%
len(dataset)
# Out:
# 0

# %%
dataset.print_stats()

# %%
import wget
url = 'https://zenodo.org/record/3587843/files/TACO.zip?download=1/taco.zip'
wget.download(url)
# Out:
# 'TACO.zip'

# %%
# %cd ..
# Out:
# /content

# %%
import zipfile

# %%
with zipfile.ZipFile('TACO.zip', 'r') as zip_ref:
    zip_ref.extractall('.')

# %%
# !git clone https://github.com/bearpaw/clothing-co-parsing.git
# Out:
# Cloning into 'clothing-co-parsing'...
# remote: Enumerating objects: 4234, done.
# remote: Total 4234 (delta 0), reused 0 (delta 0), pack-reused 4234
# Receiving objects: 100% (4234/4234), 124.59 MiB | 38.45 MiB/s, done.
# Resolving deltas: 100% (1100/1100), done.

# %%
import os 
from pathlib import Path

url = 'https://mymldatasets.s3.eu-de.cloud-object-storage.appdomain.cloud/MRIs.zip'
wget.download(url)

with zipfile.ZipFile('MRIs.zip', 'r') as zip_ref:
    zip_ref.extractall('.')

# %%
path = Path('./MRIs')
imgs1 = [path/'MRIs'/i for i in os.listdir(path/'MRIs')]
ixs1 = [i.split('_')[-1] for i in os.listdir(path/'MRIs')]
masks1 = [path/'Segmentations'/f'segm_{ix}' for ix in ixs1]

len(imgs1), len(masks1)
# Out:
# (425, 425)

# %% [markdown]
# ##PREGUNTA 3

# %%
import os 
from pathlib import Path

path = Path('./clothing-co-parsing')
imgs = [path/'photos'/i for i in os.listdir(path/'photos')]
#ixs = [i.split('_')[-1] for i in os.listdir(path/'MRIs')]
masks = [path/'annotations/pixel-level'/i for i in os.listdir(path/'annotations/pixel-level')]

len(imgs), len(masks)
# Out:
# (2099, 1004)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle as pl
from scipy import misc

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(30,10))

# with open(imgs[0], 'rb') as handle:
#     my_array = pl.load(handle)
# img = np.array(my_array)

img = np.load(imgs[0], allow_pickle=True)
mask = np.load(masks[0], allow_pickle=True)
ax1.imshow(img)
ax2.imshow(mask)
ax3.imshow(img)
ax3.imshow(mask, alpha=0.4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     446             try:
# --> 447                 return pickle.load(fid, **pickle_kwargs)
#     448             except Exception:
#
# UnpicklingError: invalid load key, '\xff'.
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-61-abca128c8a77> in <module>()
#      10 # img = np.array(my_array)
#      11
# ---> 12 img = np.load(imgs[0], allow_pickle=True)
#      13 mask = np.load(masks[0], allow_pickle=True)
#      14 ax1.imshow(img)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
# ...

# %%
img.shape, img.dtype, img.max(), img.min()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-42da03b86688> in <module>()
# ----> 1 img.shape, img.dtype, img.max(), img.min()
#
# AttributeError: 'list' object has no attribute 'shape'
